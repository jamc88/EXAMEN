# %% [markdown]
# # Recuperación
#
# ### TSMC-I: Análisis de datos en Python
#
# 22 de Febrero de 2024

# %% [markdown]
# **1. (30 puntos) Utilice los datos del Atlas de riesgo de temperaturas máximas (atr.csv en el repositorio)  realice lo siguiente:**
#
# * Limpie los datos y agregue dos columnas que contengan la intensidad minima y la intensidad máxima como aparece acontinuación:

# %% [markdown]
# ![Captura%20de%20pantalla%202024-02-22%20a%20la%28s%29%201.29.35%E2%80%AFa.m..png](attachment:Captura%20de%20pantalla%202024-02-22%20a%20la%28s%29%201.29.35%E2%80%AFa.m..png)

# %% [markdown]
# * Obtenga un Dataframe con las 3 areas más grandes registradas por alcaldia como aparece acontinuación:

# %% [markdown]
# ![Captura%20de%20pantalla%202024-02-22%20a%20la%28s%29%201.52.40%E2%80%AFa.m..png](attachment:Captura%20de%20pantalla%202024-02-22%20a%20la%28s%29%201.52.40%E2%80%AFa.m..png)

# %% [markdown]
# * Obtenga un Dataframe similar al siguiente que contenga todas las alcaldias.

# %% [markdown]
# ![Captura%20de%20pantalla%202024-02-22%20a%20la%28s%29%201.54.27%E2%80%AFa.m..png](attachment:Captura%20de%20pantalla%202024-02-22%20a%20la%28s%29%201.54.27%E2%80%AFa.m..png)

# %% [markdown]
# * Obtenga la siguiente gráfica que contiene las areas con intensidad alta y media menores a $300000m^2$

# %% [markdown]
# ![Sin%20ti%CC%81tulo.png](attachment:Sin%20ti%CC%81tulo.png)

# %% [markdown]
# **2. (20 puntos) Guarde en un solo Dataframe los datos de los 5 contaminantes principales de la zona centro de la CDMX durante los años 2018-2020 (*contam2018.xlsx - contam2020.xlsx* en Github) indexados por la fecha y con las columnas O3, SO2, NO2, CO y PM10. A continuación, realice lo siguiente:**
#
# * Obtenga las gráficas de series de tiempo de los contaminantes.
#
# * Obtenga los gráficos de caja de los contaminantes. ¿Cuál contaminante menos detectado durante 2020?
#
# * Realice una prueba de contraste de normalidad de los datos.
#
# * De acuerdo a la prueba obtenida anteriormente. ¿Cuál es el coeficiente de correlación apropiado para obtener la correlación entre los contaminantes?
#
# * Obtenga una matríz de correlación de los contaminantes. Y obtenga un Dataframe que muestre la correlación 2 a 2 entre los contaminantes.
#
# * Obtenga 3 diagramas de dispersión de los contaminantes donde existe más correlación.
#
# * Obtenga una gráfica que muestre todos los diagrama de dispersión entre todos los contaminantes.
#
# Sobre la columna del NO2, realice lo siguiente:
#
# * Particione los datos en 4 grupos y obtenga un Dataframe con el mínimo, máximo, media y frecuencia de los datos en cada grupo.
#
# * Obtenga un Dataframe indexado por trimestre que muestre la media de NO2 en cada uno de estos.
#
# * Realice una suavización con una ventana de tamaño 100. ¿Qué puede observar acerca de la estacionariedad?
#
# * Realice una prueba estadística para confirmar si los datos son o no son estacionarios.

# %% [markdown]
# **4. (30 puntos) Extraiga las tabla de "Terremotos en México" del siguiente enlace:**
#
# https://es.wikipedia.org/wiki/Anexo:Terremotos_en_M%C3%A9xico
#
# y realice lo siguiente:
#
# * Obtenga un Dataframe que contenga los terremotos de los siglos XX y XXI con las columnas:  Hora,  Magnitud, Epicentro, Zonas Afectadas  y Observaciones, indexado con la fecha. Nota. Si alguna fila no contiene la hora, coloquela como 00:00. Tome la primera magnitud que aparesca de cada terremoto.

# %% [markdown]
# ![Captura%20de%20pantalla%202024-02-22%20a%20la%28s%29%2012.12.01%E2%80%AFp.m..png](attachment:Captura%20de%20pantalla%202024-02-22%20a%20la%28s%29%2012.12.01%E2%80%AFp.m..png)

# %% [markdown]
# * Obtenga un gráfico de barras que ilustre el año del sismo y su magnitud.
#
# * Del dataframe anterior, obtenga un Dataframe que contenga todos los terremotos con magnitud mayor o igual a 9 y obtenga un gráfico de barras que ilustre esto.
#
#
# * Agrupe las magnitudes de terremotos en niveles como sigue:
#
#     nivel 1: [6.0,6.4]
#
#     nivel 2: [6.5,6.9]
#
#     nivel 3: [7.0,7.4]
#
#     nivel 4: [7.5,7.9]
#
#     nivel 5: [8.0,8.4]
#
# Posteriormente agregue una columna al dataframe que indique el nivel.

# %% [markdown]
#  **5. (10 puntos) Cargue los datos de los precios en bolsa del Bitcoin (BTC-USD.csv en github) correspondientes a los años 2019-2023 y realice lo siguiente:**
#
# * Obtenga un índice datetime de nombre 'Date' con las fechas correspondientes e indexe los datos.
#
# * Obtenga una gráfica de la serie temporal de los precios de Cierre y la de sus rendimientos.
#
# * Obtenga un DataFrame indexado por el año que muestre el precio de cierre medio por cada año.
#
# * Describa la distribución de los precios de cierre utilizando el Teorema de Chebyshev ó la Regla empírica (si es aplicable).
#
# * Obtenga el precio de cierre más alto y el precio de cierre más bajo a partir del 2020.
#
# * Obtenga las gráficas de caja de los años registrados.
#
# * ¿Los precios de los rendimientos se distribuyen normalmente? Justifique su respuesta.

# %% [markdown]
# **6. (10 puntos)Cargue los datos de personas   registradas en el Registro Nacional de Personas Desaparecidas y No Localizadas (RNPDNO), actualizado hasta agosto de 2023 (VP_RNPDNO_2023.csv). Posteriormente, realice lo siguiente:**
#
# * Coloque correctamente en nombre de las columnas.
#
# * Sustituya con un 0 los valores nulos y las cadenas 'ELIMINADO 2' en la columna edad.
#
# * Sustituya las cadenas 'ELIMINADO 5' por '01/01/24' en la columna Fecha de desaparición.
#
# * El resto de cadenas que contiene la cadena 'ELIMINADO' deben ser sustituidas por 'SE DESCONOCE'.
#
# * Agregue una columna del año de desaparición.
#
# * Indexe el Dataframe por fecha de desaparición con un índice datetime y ordene el índice en orden ascendente.
#
# * Elimine las filas con fechas posteriores al año 2024 (use el método truncate).
#
# * Obtenga un Dataframe indexado por año (2010 al 2023) que contenga el número de personas registradas en el RNPDNO por año.
#
# * ¿Qué porcentaje de personas registradas en el RNPDNO no tiene fecha de registro de desaparición?
#
# * ¿Cuántas personas hay por sexo, registradas en el RNPDNO? Obtenga un gráfico que ilustre esto.
#
# * Obtenga un Dataframe de personas registradas en el RNPDNO por entidad de desaparición (en orden descendente) y obtenga un gráfico que ilustre esto.
